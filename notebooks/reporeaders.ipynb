# %%
import sys; sys.path.append('..')
from multiprompt import *
from multiprompt.repo2llm import *

# %%
reader = LocalReader('/Users/ryan/github/multiprompt')
reader.pathdata
# Out:
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# WARNING:multiprompt.imports:Unsupported file extension: rs
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# WARNING:multiprompt.imports:Unsupported file extension: rs
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# WARNING:multiprompt.imports:Unsupported file extension: rs
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# ERROR:multiprompt.imports:'int' object has no attribute 'split'
# [{'filename': 'requirements.txt',
#   'path_rel': 'requirements.txt',
#   'path_abs': '/Users/ryan/github/multiprompt/requirements.txt',
#   'filesize': 178,
#   'num_tokens': 0},
#  {'filename': 'README.md',
#   'path_rel': 'README.md',
#   'path_abs': '/Users/ryan/github/multiprompt/README.md',
#   'filesize': 1235,
#   'num_tokens': 0},
#  {'filename': 'setup.py',
#   'path_rel': 'setup.py',
#   'path_abs': '/Users/ryan/github/multiprompt/setup.py',
#   'filesize': 1223,
#   'num_tokens': 0},
#  {'filename': 'package.json',
#   'path_rel': 'package.json',
#   'path_abs': '/Users/ryan/github/multiprompt/package.json',
#   'filesize': 1530,
#   'num_tokens': 0},
#  {'filename': 'run_server.py',
#   'path_rel': 'run_server.py',
#   'path_abs': '/Users/ryan/github/multiprompt/run_server.py',
#   'filesize': 271,
#   'num_tokens': 0},
#  {'filename': 'db.py',
#   'path_rel': 'multiprompt/db.py',
#   'path_abs': '/Users/ryan/github/multiprompt/multiprompt/db.py',
#   'filesize': 736,
#   'num_tokens': 0},
#  {'filename': 'server.py',
#   'path_rel': 'multiprompt/server.py',
#   'path_abs': '/Users/ryan/github/multiprompt/multiprompt/server.py',
#   'filesize': 2961,
#   'num_tokens': 0},
#  {'filename': 'multiprompt.py',
#   'path_rel': 'multiprompt/multiprompt.py',
#   'path_abs': '/Users/ryan/github/multiprompt/multiprompt/multiprompt.py',
#   'filesize': 93,
#   'num_tokens': 0},
#  {'filename': '__init__.py',
#   'path_rel': 'multiprompt/__init__.py',
#   'path_abs': '/Users/ryan/github/multiprompt/multiprompt/__init__.py',
#   'filesize': 26,
#   'num_tokens': 0},
#  {'filename': 'repo2llm.py',
#   'path_rel': 'multiprompt/repo2llm.py',
#   'path_abs': '/Users/ryan/github/multiprompt/multiprompt/repo2llm.py',
#   'filesize': 10221,
#   'num_tokens': 0},
#  {'filename': 'agents.py',
#   'path_rel': 'multiprompt/agents.py',
#   'path_abs': '/Users/ryan/github/multiprompt/multiprompt/agents.py',
#   'filesize': 1476,
#   'num_tokens': 0},
#  {'filename': 'imports.py',
#   'path_rel': 'multiprompt/imports.py',
#   'path_abs': '/Users/ryan/github/multiprompt/multiprompt/imports.py',
#   'filesize': 5255,
#   'num_tokens': 0},
#  {'filename': 'cli.py',
#   'path_rel': 'multiprompt/cli.py',
#   'path_abs': '/Users/ryan/github/multiprompt/multiprompt/cli.py',
#   'filesize': 1126,
#   'num_tokens': 0},
#  {'filename': 'utils.py',
#   'path_rel': 'multiprompt/utils.py',
#   'path_abs': '/Users/ryan/github/multiprompt/multiprompt/utils.py',
#   'filesize': 2456,
#   'num_tokens': 0},
#  {'filename': 'llms.py',
#   'path_rel': 'multiprompt/llms.py',
#   'path_abs': '/Users/ryan/github/multiprompt/multiprompt/llms.py',
#   'filesize': 7354,
#   'num_tokens': 0},
#  {'filename': 'conversations.py',
#   'path_rel': 'multiprompt/conversations.py',
#   'path_abs': '/Users/ryan/github/multiprompt/multiprompt/conversations.py',
#   'filesize': 7977,
#   'num_tokens': 0},
#  {'filename': 'workflows.ipynb',
#   'path_rel': 'notebooks/workflows.ipynb',
#   'path_abs': '/Users/ryan/github/multiprompt/notebooks/workflows.ipynb',
#   'filesize': 14230,
#   'num_tokens': 0},
#  {'filename': 'reporeaders.ipynb',
#   'path_rel': 'notebooks/reporeaders.ipynb',
#   'path_abs': '/Users/ryan/github/multiprompt/notebooks/reporeaders.ipynb',
#   'filesize': 0,
#   'num_tokens': 0},
#  {'filename': 'index.html',
#   'path_rel': 'public/index.html',
#   'path_abs': '/Users/ryan/github/multiprompt/public/index.html',
#   'filesize': 1721,
#   'num_tokens': 0},
#  {'filename': 'manifest.json',
#   'path_rel': 'public/manifest.json',
#   'path_abs': '/Users/ryan/github/multiprompt/public/manifest.json',
#   'filesize': 492,
#   'num_tokens': 0},
#  {'filename': 'robots.txt',
#   'path_rel': 'public/robots.txt',
#   'path_abs': '/Users/ryan/github/multiprompt/public/robots.txt',
#   'filesize': 67,
#   'num_tokens': 0},
#  {'filename': 'constants.js',
#   'path_rel': 'src/constants.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/constants.js',
#   'filesize': 5104,
#   'num_tokens': 0},
#  {'filename': 'reportWebVitals.js',
#   'path_rel': 'src/reportWebVitals.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/reportWebVitals.js',
#   'filesize': 362,
#   'num_tokens': 0},
#  {'filename': 'index.js',
#   'path_rel': 'src/index.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/index.js',
#   'filesize': 244,
#   'num_tokens': 0},
#  {'filename': 'setupTests.js',
#   'path_rel': 'src/setupTests.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/setupTests.js',
#   'filesize': 241,
#   'num_tokens': 0},
#  {'filename': 'App.js',
#   'path_rel': 'src/App.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/App.js',
#   'filesize': 1127,
#   'num_tokens': 0},
#  {'filename': 'Cargo.toml',
#   'path_rel': 'src-tauri/Cargo.toml',
#   'path_abs': '/Users/ryan/github/multiprompt/src-tauri/Cargo.toml',
#   'filesize': 1105,
#   'num_tokens': 0},
#  {'filename': 'tauri.conf.json',
#   'path_rel': 'src-tauri/tauri.conf.json',
#   'path_abs': '/Users/ryan/github/multiprompt/src-tauri/tauri.conf.json',
#   'filesize': 1848,
#   'num_tokens': 0},
#  {'filename': 'build.rs',
#   'path_rel': 'src-tauri/build.rs',
#   'path_abs': '/Users/ryan/github/multiprompt/src-tauri/build.rs',
#   'filesize': 37,
#   'num_tokens': 0},
#  {'filename': 'embedded_server.rs',
#   'path_rel': 'src-tauri/src/embedded_server.rs',
#   'path_abs': '/Users/ryan/github/multiprompt/src-tauri/src/embedded_server.rs',
#   'filesize': 2033,
#   'num_tokens': 0},
#  {'filename': 'main.rs',
#   'path_rel': 'src-tauri/src/main.rs',
#   'path_abs': '/Users/ryan/github/multiprompt/src-tauri/src/main.rs',
#   'filesize': 1995,
#   'num_tokens': 0},
#  {'filename': 'Layout.js',
#   'path_rel': 'src/components/Layout.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/Layout.js',
#   'filesize': 1773,
#   'num_tokens': 0},
#  {'filename': 'PromptConfig.js',
#   'path_rel': 'src/components/PromptConfig.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/PromptConfig.js',
#   'filesize': 8612,
#   'num_tokens': 0},
#  {'filename': 'GridLayout.js',
#   'path_rel': 'src/components/GridLayout.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/GridLayout.js',
#   'filesize': 1917,
#   'num_tokens': 0},
#  {'filename': 'AgentCard.js',
#   'path_rel': 'src/components/AgentCard.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/AgentCard.js',
#   'filesize': 3870,
#   'num_tokens': 0},
#  {'filename': 'ToastContainer.js',
#   'path_rel': 'src/components/ToastContainer.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/ToastContainer.js',
#   'filesize': 2542,
#   'num_tokens': 0},
#  {'filename': 'IconSidebar.js',
#   'path_rel': 'src/components/IconSidebar.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/IconSidebar.js',
#   'filesize': 2763,
#   'num_tokens': 0},
#  {'filename': 'MarkdownRenderer.js',
#   'path_rel': 'src/components/MarkdownRenderer.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/MarkdownRenderer.js',
#   'filesize': 1692,
#   'num_tokens': 0},
#  {'filename': 'UserCard.js',
#   'path_rel': 'src/components/UserCard.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/UserCard.js',
#   'filesize': 1356,
#   'num_tokens': 0},
#  {'filename': 'WorkflowModal.js',
#   'path_rel': 'src/components/WorkflowModal.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/WorkflowModal.js',
#   'filesize': 2830,
#   'num_tokens': 0},
#  {'filename': 'ConversationHistory.js',
#   'path_rel': 'src/components/ConversationHistory.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/ConversationHistory.js',
#   'filesize': 1309,
#   'num_tokens': 0},
#  {'filename': 'ConfigModal.js',
#   'path_rel': 'src/components/ConfigModal.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/ConfigModal.js',
#   'filesize': 2336,
#   'num_tokens': 0},
#  {'filename': 'AgentConfigForm.js',
#   'path_rel': 'src/components/AgentConfigForm.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/AgentConfigForm.js',
#   'filesize': 6329,
#   'num_tokens': 0},
#  {'filename': 'ConfigModal.css',
#   'path_rel': 'src/components/ConfigModal.css',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/ConfigModal.css',
#   'filesize': 39,
#   'num_tokens': 0},
#  {'filename': 'Messages.css',
#   'path_rel': 'src/components/Messages.css',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/Messages.css',
#   'filesize': 483,
#   'num_tokens': 0},
#  {'filename': 'ModalManager.js',
#   'path_rel': 'src/components/ModalManager.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/ModalManager.js',
#   'filesize': 799,
#   'num_tokens': 0},
#  {'filename': 'Messages.js',
#   'path_rel': 'src/components/Messages.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/components/Messages.js',
#   'filesize': 2159,
#   'num_tokens': 0},
#  {'filename': 'SocketContext.js',
#   'path_rel': 'src/contexts/SocketContext.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/contexts/SocketContext.js',
#   'filesize': 1975,
#   'num_tokens': 0},
#  {'filename': 'AgentContext.js',
#   'path_rel': 'src/contexts/AgentContext.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/contexts/AgentContext.js',
#   'filesize': 659,
#   'num_tokens': 0},
#  {'filename': 'ConfigContext.js',
#   'path_rel': 'src/contexts/ConfigContext.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/contexts/ConfigContext.js',
#   'filesize': 599,
#   'num_tokens': 0},
#  {'filename': 'ThemeContext.js',
#   'path_rel': 'src/contexts/ThemeContext.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/contexts/ThemeContext.js',
#   'filesize': 2167,
#   'num_tokens': 0},
#  {'filename': 'DirectoryReaderContext.js',
#   'path_rel': 'src/contexts/DirectoryReaderContext.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/contexts/DirectoryReaderContext.js',
#   'filesize': 2387,
#   'num_tokens': 0},
#  {'filename': 'LLMProvider.js',
#   'path_rel': 'src/contexts/LLMProvider.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/contexts/LLMProvider.js',
#   'filesize': 7372,
#   'num_tokens': 0},
#  {'filename': 'models.json',
#   'path_rel': 'src/data/models.json',
#   'path_abs': '/Users/ryan/github/multiprompt/src/data/models.json',
#   'filesize': 2311,
#   'num_tokens': 0},
#  {'filename': 'agents.json',
#   'path_rel': 'src/data/agents.json',
#   'path_abs': '/Users/ryan/github/multiprompt/src/data/agents.json',
#   'filesize': 9932,
#   'num_tokens': 0},
#  {'filename': 'useAgentInteraction.js',
#   'path_rel': 'src/hooks/useAgentInteraction.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/hooks/useAgentInteraction.js',
#   'filesize': 543,
#   'num_tokens': 0},
#  {'filename': 'useStore.js',
#   'path_rel': 'src/store/useStore.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/store/useStore.js',
#   'filesize': 10830,
#   'num_tokens': 0},
#  {'filename': 'uiSlice.js',
#   'path_rel': 'src/store/slices/uiSlice.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/store/slices/uiSlice.js',
#   'filesize': 335,
#   'num_tokens': 0},
#  {'filename': 'workflowSlice.js',
#   'path_rel': 'src/store/slices/workflowSlice.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/store/slices/workflowSlice.js',
#   'filesize': 1207,
#   'num_tokens': 0},
#  {'filename': 'configSlice.js',
#   'path_rel': 'src/store/slices/configSlice.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/store/slices/configSlice.js',
#   'filesize': 636,
#   'num_tokens': 0},
#  {'filename': 'conversationSlice.js',
#   'path_rel': 'src/store/slices/conversationSlice.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/store/slices/conversationSlice.js',
#   'filesize': 1215,
#   'num_tokens': 0},
#  {'filename': 'agentSlice.js',
#   'path_rel': 'src/store/slices/agentSlice.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/store/slices/agentSlice.js',
#   'filesize': 2219,
#   'num_tokens': 0},
#  {'filename': 'referenceSlice.js',
#   'path_rel': 'src/store/slices/referenceSlice.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/store/slices/referenceSlice.js',
#   'filesize': 420,
#   'num_tokens': 0},
#  {'filename': 'index.css',
#   'path_rel': 'src/styles/index.css',
#   'path_abs': '/Users/ryan/github/multiprompt/src/styles/index.css',
#   'filesize': 15893,
#   'num_tokens': 0},
#  {'filename': 'logger.js',
#   'path_rel': 'src/utils/logger.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/utils/logger.js',
#   'filesize': 307,
#   'num_tokens': 0},
#  {'filename': 'promptUtils.js',
#   'path_rel': 'src/utils/promptUtils.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/utils/promptUtils.js',
#   'filesize': 3491,
#   'num_tokens': 0},
#  {'filename': 'agentUtils.js',
#   'path_rel': 'src/utils/agentUtils.js',
#   'path_abs': '/Users/ryan/github/multiprompt/src/utils/agentUtils.js',
#   'filesize': 602,
#   'num_tokens': 0}]
